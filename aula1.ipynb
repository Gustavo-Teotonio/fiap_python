# %% [markdown]
# # Primeiro código (média de notas)

# %%
# variáveis de entrada

n1 = 5
n2 = 9
n3 = 6

#Calculo da méida
media = (n1 + n2 + n3) / 3

print(f"A média é: {media}")
# Out:
# A média é: 6.666666666666667

# %%
def chama_valores():
    n1 = float(input("Digite a primeira nota"))
    n2 = float(input("Digite a segunda nota: "))
    n3 = float(input("Digite a terceira nota"))

    nota_final = (n1+n2+n3)/3

    if(nota_final >= 6):
        print(f"Aprovado. Média: {nota_final}")
    else:
        print(f"Reprovado {nota_final}")

chama_valores()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 13
#      10     else:
#      11         print(f"Reprovado {nota_final}")
# ---> 13 chama_valores()
#
# Cell In[14], line 3, in chama_valores()
#       1 def chama_valores():
#       2     n1 = float(input("Digite a primeira nota"))
# ----> 3     n2 = float(input("Digite a segunda nota: "))
#       4     n3 = float(input("Digite a terceira nota"))
#       6     nota_final = (n1+n2+n3)/3
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# # Exercício 1 - Calculo da área do circulo

# %%
pi = 3.14\                                                                                                                                                                       
raio = float(input("Raio: "))
print(f"Área do circulo: {(raio ** 2) * pi}")
# Out:
# Área do circulo: 78.5

# %% [markdown]
# # Exercício 2 - Calculo da área de um retangulo

# %%
l1 = float(input("Lado 1: "))
l2 = float(input("Lado 2: "))

print(f"Área: {l1 * l2}")
# Out:
# Área: 50.0

# %% [markdown]
# # Desafio 3 Área do triângulo

# %%
l1 = float(input("Base: "))
l2 = float(input("Altura: "))

print(f"Área: {l1 * l2 / 2}")
# Out:
# Área: 16.0
