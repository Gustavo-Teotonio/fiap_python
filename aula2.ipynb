# %% [markdown]
# # EX3

# %%
km = int(input('Digite os km'))

print(f"Metros: {km * 1000}")
print(f"Centimetros: {km * 100000}")
# Out:
# Metros: 100000
# Centimetros: 10000000

# %% [markdown]
# # EX4

# %%
distancia = float(input("Medida: "))
tempo = float(input("Horas: "))
print(f"Km/h: {distancia / tempo}")
# Out:
# Km/h: 5.0

# %% [markdown]
# # EX5

# %%
massa = float(input("Massa: "))

print(f"Energia: {massa * 3*10**8}")

print(f"{massa:.2f}")
# Out:
# Energia: 1500000000.0
# 5.00

# %% [markdown]
# # EX6

# %%
# a^2 = b^2 + c^2

a = float(input("Digite a: "))

c = float(input("Digite c: "))

b = (a**2 - c**2)**0.5

print(f"{b}")
# Out:
# 36.0 = 100.0 - 64.0

# %% [markdown]
# #Ex7

# %%
nome = input("Nome: ")

sobrenome = input("Sobrenome: ")

cpf = input("CPF: ")

endereco = input("Endereço: ")

cep = input("CEP: ")

nome_completo = nome + " " + sobrenome

print(f"{nome_completo}")

print(f"Nome Completo: {nome_completo} - CPF: {cpf}")

print(f"Endereço: {endereco} - CEP: {cep}")
# Out:
# gustavo teotonio
# gustavo teotonio44496050803
# rua olimpia 2406162060
