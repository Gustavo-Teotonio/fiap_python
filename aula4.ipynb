# %% [markdown]
# # Aula 4 - Estrutura de repetição

# %% [markdown]
# # Ex1 - Calcule a soma dos números de 1 a 100

# %%
num = 0

for i in range(1, 100):
    num += i

print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 for i in range(1, 100):
# ----> 2     num += i
#       4 print(num)
#
# NameError: name 'num' is not defined

# %% [markdown]
# #Ex2. Imprima quais são os números pares de 1 a 50 e calcule a soma dos valores pares
